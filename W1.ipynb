# %%
#data types
pi = 3.12
print(type(pi))
# Out:
# <class 'float'>

# %%
#reading + writing + verifying data
age = input("your age: ");
if age.isdigit():
    print(f"I'm {age} years old")
else: print("Error 404: invalid input")
# Out:
# your age:  100
# I'm 100 years old
